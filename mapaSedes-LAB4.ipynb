# %%
import folium

from folium.plugins import minimap

CR=folium.Map(location=(9.771934133360991, -84.05264988840347),zoom_start=8.5)

# %%
popuptext=['<b>Universidad Nacional Campus Nicoya</b>',
           '<b>Universidad Nacional Campus Omar Dengo</b>',
           '<b>Universidad Nacional Campus Benjamín Núñez</b>',
           '<b>Universidad Nacional Campus Sarapiquí</b>',
           '<b>Universidad Nacional Campus Pérez Zeledón</b>',
           '<b>Universidad Nacional Campus Liberia</b>',
           '<b>Universidad Nacional Campus Coto</b>',
           '<b>Universidad Nacional Sede Interuniversitaria</b>']

folium.Marker(location=[10.135233123638425, -85.446650402735],popup=popuptext[0], icon=folium.Icon (color="red",icon="ok-sign")).add_to(CR)
folium.Marker(location=[9.998935598007472, -84.11148159954315],popup=popuptext[1], icon=folium.Icon (color="red",icon="ok-sign")).add_to(CR)
folium.Marker(location=[9.9711128858209, -84.1283902818418],popup=popuptext[2], icon=folium.Icon (color="red",icon="ok-sign")).add_to(CR)
folium.Marker(location=[10.319313638899011, -83.92275780035052],popup=popuptext[3], icon=folium.Icon (color="red",icon="ok-sign")).add_to(CR)
folium.Marker(location=[9.379973856580229, -83.69152492918579],popup=popuptext[4], icon=folium.Icon (color="red",icon="ok-sign")).add_to(CR)
folium.Marker(location=[10.617733565757085, -85.45142872918575],popup=popuptext[5], icon=folium.Icon (color="red",icon="ok-sign")).add_to(CR)
folium.Marker(location=[8.573867580124242, -82.87246332637606],popup=popuptext[6], icon=folium.Icon (color="red",icon="ok-sign")).add_to(CR)
folium.Marker(location=[10.019997989551348, -84.19702533275755],popup=popuptext[7], icon=folium.Icon (color="red",icon="ok-sign")).add_to(CR)


CR
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
